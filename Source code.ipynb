# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Loading Dataset

# %%
#reading dataset to environment
path= "C://Users//gorla//OneDrive//Documents//darshini//user.csv"  #Place the saved Location of dataset
DS= pd.read_csv(path)  #THE NAME OF THE DATASET IN THIS ENVIRONMENT

#printing dataset
print(DS)
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 1          2           OnePlus 9          Android                       268
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 4          5           iPhone 12              iOS                       187
# ..       ...                 ...              ...                       ...
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
# ...

# %% [markdown]
# # Understanding Dataset

# %%
#To get summarized statistics on numerical columns
DS.describe()
# Out:
#          User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  700.00000                700.000000                  700.000000
# mean   350.50000                271.128571                    5.272714
# std    202.21688                177.199484                    3.068584
# min      1.00000                 30.000000                    1.000000
# 25%    175.75000                113.250000                    2.500000
# 50%    350.50000                227.500000                    4.900000
# 75%    525.25000                434.250000                    7.400000
# max    700.00000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               700.000000                700.000000           700.000000
# mean               1525.158571                 50.681429           929.742857
# std                 819.136414                 26.943324           640.451729
# ...

# %%
#To print column values in taken DataSet "DS"
print(DS.columns)
# Out:
# Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='object')

# %%
#To get n (eg:10) entities values in the dataset
print(DS.head(10))
# Out:
#    User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0        1      Google Pixel 5          Android                       393
# 1        2           OnePlus 9          Android                       268
# 2        3        Xiaomi Mi 11          Android                       154
# 3        4      Google Pixel 5          Android                       239
# 4        5           iPhone 12              iOS                       187
# 5        6      Google Pixel 5          Android                        99
# 6        7  Samsung Galaxy S21          Android                       350
# 7        8           OnePlus 9          Android                       543
# 8        9  Samsung Galaxy S21          Android                       340
# 9       10           iPhone 12              iOS                       424
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# ...

# %%
#printing datatypes in dataset
type= DS.dtypes
print(type)
# Out:
# User ID                         int64
# Device Model                   object
# Operating System               object
# App Usage Time (min/day)        int64
# Screen On Time (hours/day)    float64
# Battery Drain (mAh/day)         int64
# Number of Apps Installed        int64
# Data Usage (MB/day)             int64
# Age                             int64
# Gender                         object
# User Behavior Class             int64
# dtype: object

# %% [markdown]
# # Data Integrity

# %%
#printing count of null values
null_count= DS.isnull().sum()
print(null_count)
# Out:
# User ID                       0
# Device Model                  0
# Operating System              0
# App Usage Time (min/day)      0
# Screen On Time (hours/day)    0
# Battery Drain (mAh/day)       0
# Number of Apps Installed      0
# Data Usage (MB/day)           0
# Age                           0
# Gender                        0
# User Behavior Class           0
# dtype: int64

# %%
#printing sum of empty string values
empty= (DS=="").sum()
print(empty)
# Out:
# User ID                       0
# Device Model                  0
# Operating System              0
# App Usage Time (min/day)      0
# Screen On Time (hours/day)    0
# Battery Drain (mAh/day)       0
# Number of Apps Installed      0
# Data Usage (MB/day)           0
# Age                           0
# Gender                        0
# User Behavior Class           0
# dtype: int64

# %%
#to get duplicate rows in dataset
dupe= DS.duplicated()
print(dupe)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 695    False
# 696    False
# 697    False
# 698    False
# 699    False
# Length: 700, dtype: bool

# %%
#to get duplicate values in column "Gender"
dup= DS['Gender'].duplicated()
print(dup)
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 695     True
# 696     True
# 697     True
# 698     True
# 699     True
# Name: Gender, Length: 700, dtype: bool

# %% [markdown]
# # Data Selection

# %%
 #Filtering columns or rows based on user condition
apps_50= DS[DS['Number of Apps Installed']>95]
print(apps_50.head(5))
print("The number of entities are: ")
print(len(apps_50))
# Out:
#     User ID  Device Model Operating System  App Usage Time (min/day)  \
# 45       46  Xiaomi Mi 11          Android                       502
# 46       47     OnePlus 9          Android                       558
# 68       69     iPhone 12              iOS                       516
# 71       72     iPhone 12              iOS                       521
# 80       81     OnePlus 9          Android                       565
#
#     Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 45                        10.9                     2476
# 46                         8.4                     2447
# 68                        10.2                     2932
# 71                         9.0                     2902
# 80                        10.6                     2475
#
#     Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 45                        96                 1935   39    Male
# 46                        97                 1594   22  Female
# ...

# %%
 #Retrieves rows that have less than 2hrs(120 min) screen time
time_fill= DS[DS['App Usage Time (min/day)']<120]
print(time_fill)
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 5          6      Google Pixel 5          Android                        99
# 10        11      Google Pixel 5          Android                        53
# 18        19      Google Pixel 5          Android                        81
# 20        21  Samsung Galaxy S21          Android                        93
# 25        26  Samsung Galaxy S21          Android                        91
# ..       ...                 ...              ...                       ...
# 679      680           iPhone 12              iOS                        33
# 683      684  Samsung Galaxy S21          Android                        75
# 695      696           iPhone 12              iOS                        92
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
#
# ...

# %%
 #For sorting any column in a dataset(in either ascending or descending order)
sorting= DS.sort_values(by='App Usage Time (min/day)',ascending=False)
print(sorting)
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 367      368           OnePlus 9          Android                       598
# 341      342           iPhone 12              iOS                       597
# 184      185        Xiaomi Mi 11          Android                       597
# 166      167      Google Pixel 5          Android                       595
# 654      655      Google Pixel 5          Android                       594
# ..       ...                 ...              ...                       ...
# 35        36  Samsung Galaxy S21          Android                        32
# 73        74        Xiaomi Mi 11          Android                        31
# 337      338  Samsung Galaxy S21          Android                        30
# 355      356  Samsung Galaxy S21          Android                        30
# 244      245           OnePlus 9          Android                        30
#
# ...

# %%
 #Printing unique values from the specified column
unique_values= DS['Operating System'].unique()
print(unique_values)
# Out:
# ['Android' 'iOS']

# %%
#Retrieving rows based on a condition
model_type= DS[DS['Device Model']=='iPhone 12']
print(model_type)
# Out:
#      User ID Device Model Operating System  App Usage Time (min/day)  \
# 4          5    iPhone 12              iOS                       187
# 9         10    iPhone 12              iOS                       424
# 14        15    iPhone 12              iOS                       189
# 17        18    iPhone 12              iOS                       299
# 19        20    iPhone 12              iOS                       577
# ..       ...          ...              ...                       ...
# 668      669    iPhone 12              iOS                       170
# 670      671    iPhone 12              iOS                        81
# 679      680    iPhone 12              iOS                        33
# 691      692    iPhone 12              iOS                       178
# 695      696    iPhone 12              iOS                        92
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 4                           4.3                     1367
# ...

# %%
count=len(model_type)
print(count)
# Out:
# 146

# %% [markdown]
# # Data Transformation

# %%
 #Calculating mean battery drain for each device model and store it in a column
DS['mean_battery_drain']= DS.groupby('Device Model')['Battery Drain (mAh/day)'].transform('mean')

 #Calculating mean data usage for each device model and store it in another column
DS['mean_data_usage']= DS.groupby('Device Model')['Data Usage (MB/day)'].transform('mean')

#Displaying the updated DataFrame
DS
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 1          2           OnePlus 9          Android                       268
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 4          5           iPhone 12              iOS                       187
# ..       ...                 ...              ...                       ...
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
# ...

# %% [markdown]
# # Feature Engineering

# %%
 #Creating a new feature: Battery Efficiency
DS['Battery Efficiency']= DS['Battery Drain (mAh/day)']/DS['Screen On Time (hours/day)']
print(DS[['Battery Drain (mAh/day)','Screen On Time (hours/day)','Battery Efficiency']].head(10))
# Out:
#    Battery Drain (mAh/day)  Screen On Time (hours/day)  Battery Efficiency
# 0                     1872                         6.4          292.500000
# 1                     1331                         4.7          283.191489
# 2                      761                         4.0          190.250000
# 3                     1676                         4.8          349.166667
# 4                     1367                         4.3          317.906977
# 5                      940                         2.0          470.000000
# 6                     1802                         7.3          246.849315
# 7                     2956                        11.4          259.298246
# 8                     2138                         7.7          277.662338
# 9                     1957                         6.6          296.515152

# %% [markdown]
# # Statistical Analysis

# %%
 #to print maximum values of a column
 #Here, max_perc is a column that shows the percentage battery drain values
DS['max_perc']= (DS['Battery Drain (mAh/day)'] / DS['Battery Drain (mAh/day)'].max())*100
print(DS['max_perc'])
# Out:
# 0      62.545941
# 1      44.470431
# 2      25.425994
# 3      55.997327
# 4      45.673238
#          ...
# 695    36.151019
# 696    65.653191
# 697    31.473438
# 698    14.400267
# 699    43.635149
# Name: max_perc, Length: 700, dtype: float64

# %%
 #to print minimum values of a column
 #Here, min_perc is a column that shows the minimum values
DS['min_perc']= (DS['Number of Apps Installed'] / DS['Number of Apps Installed'].min())*100
print(DS['min_perc'])
# Out:
# 0      670.0
# 1      420.0
# 2      320.0
# 3      560.0
# 4      580.0
#        ...
# 695    260.0
# 696    680.0
# 697    220.0
# 698    130.0
# 699    490.0
# Name: min_perc, Length: 700, dtype: float64

# %%
 #Finding mean value of a column(Ex: Data Usage (MB/day))
mean_val= DS['Data Usage (MB/day)'].mean()
print(mean_val)
# Out:
# 929.7428571428571

# %%
 #Finding median value of a column(Ex: Data Usage (MB/day))
median_val= DS['Data Usage (MB/day)'].median()
print(median_val)
# Out:
# 823.5

# %%
 #Finding mode value of a column(Ex: Data Usage (MB/day))
mode_val= DS['Data Usage (MB/day)'].mode()[0]
print(mode_val)
# Out:
# 122

# %%
 #Applying standard deviation on a specific column
std_val= DS['Data Usage (MB/day)'].std()
print(std_val)
# Out:
# 640.4517291185031

# %%
 #To print sum of all values in a column
sum_sc= DS['Screen On Time (hours/day)'].sum()
print(sum_sc)
# Out:
# 3690.9

# %%
  #Minimum value in a column
min_sc= DS['Screen On Time (hours/day)'].min()
print(min_sc)
 
 #Maximum value in a column
max_sc= DS['Screen On Time (hours/day)'].max()
print(max_sc)

  #Range of the column
range_sc= max_sc-min_sc
print(range_sc)
# Out:
# 1.0
# 12.0
# 11.0

# %%
 #Identifies unique column values("Female", "Male"), and converts to numerical values.
le=LabelEncoder()
DS['Gender']=le.fit_transform(DS['Gender'])
print(DS['Gender'])
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 695    1
# 696    1
# 697    0
# 698    1
# 699    0
# Name: Gender, Length: 700, dtype: int32

# %%
 #Filter rows for finding upper outliers
upper= DS[DS['Data Usage (MB/day)'] >(mean_val+2*std_val)]
print(upper)
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 37        38  Samsung Galaxy S21          Android                       522
# 41        42           OnePlus 9          Android                       576
# 48        49      Google Pixel 5          Android                       580
# 57        58           OnePlus 9          Android                       539
# 111      112        Xiaomi Mi 11          Android                       488
# 122      123      Google Pixel 5          Android                       584
# 125      126  Samsung Galaxy S21          Android                       535
# 166      167      Google Pixel 5          Android                       595
# 182      183           iPhone 12              iOS                       544
# 200      201  Samsung Galaxy S21          Android                       495
# 215      216           OnePlus 9          Android                       553
# ...

# %%
 #Filter rows for finding lower outliers
lower= DS[DS['Data Usage (MB/day)'] <(mean_val-2*std_val)]
print(lower)
# Out:
# Empty DataFrame
# Columns: [User ID, Device Model, Operating System, App Usage Time (min/day), Screen On Time (hours/day), Battery Drain (mAh/day), Number of Apps Installed, Data Usage (MB/day), Age, Gender, User Behavior Class, mean_battery_drain, mean_data_usage, Battery Efficiency, max_perc, min_perc]
# Index: []

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Bar Graph

# %%
 #Bar Graph Visualization (Vertical)
DS['Group']= pd.cut(DS['Age'],bins=[0,10,20,30,40,50,60,70],labels=['0-10','11-20','21-30','31-40','41-50','51-60','61-70'])

 # Now plot the bar chart with the grouped data
age_grp= DS.groupby('Group',observed=False)['Number of Apps Installed'].sum()

plt.bar(age_grp.index,age_grp,color='#367588')
 #title of the bar graph
plt.title('Bar Graph')
 #label for the x-axis
plt.xlabel('Age')
 #label for the y-axis
plt.ylabel('Number of Apps Installed')
 #displaying visualization using method: show()
plt.show()

# %%
 #Bar Graph Visualisation (Horizontal) 
plt.figure(figsize=(8, 6))
plt.barh(age_grp.index,age_grp,color='#367588')
plt.title('Bar Graph')
plt.xlabel('Age')
plt.ylabel('Number of Apps Installed')
plt.show()

# %% [markdown]
# ## Line Plot

# %%
 #Line Plot Visualization
reduced_data=DS['App Usage Time (min/day)'][::5]
plt.plot(reduced_data,color='#F4A300')
plt.title("Plot of App Usage")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# ## Histogram

# %%
 #Histogram Visualisation
plt.hist(DS['App Usage Time (min/day)'],color='skyblue',edgecolor='black',bins=12) 
plt.title('App Activity')
plt.xlabel('App usage')
plt.ylabel('Use time')
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
#Scatter plot visualisation
sb.scatterplot(x='App Usage Time (min/day)', y='Battery Drain (mAh/day)',data=DS,hue='Battery Drain (mAh/day)',palette='viridis',s=75,edgecolor='w') 
   #title of the Scatterplot
plt.title('Usage vs Battery bleed',fontweight='bold')
plt.xlabel('App Usage Time')
plt.ylabel('Battery Drain')
   #displaying scatter plot
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
 #selecting columns having numerical values 
num_cols= DS.select_dtypes(include=['int64','float64']).columns

 #Here, we are filtering only integer and floating value columns
print(num_cols)
# Out:
# Index(['User ID', 'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'User Behavior Class',
#        'mean_battery_drain', 'mean_data_usage', 'Battery Efficiency',
#        'max_perc', 'min_perc'],
#       dtype='object')

# %%
#creating a correlation matrix of dataset "DS"
correlation_matrix= DS[num_cols].corr()
print(correlation_matrix)
# Out:
#                              User ID  App Usage Time (min/day)  \
# User ID                     1.000000                 -0.024957
# App Usage Time (min/day)   -0.024957                  1.000000
# Screen On Time (hours/day) -0.014287                  0.950333
# Battery Drain (mAh/day)    -0.019377                  0.956385
# Number of Apps Installed   -0.023914                  0.955253
# Data Usage (MB/day)        -0.014527                  0.942308
# Age                         0.045188                  0.004382
# User Behavior Class        -0.016242                  0.970498
# mean_battery_drain         -0.002543                  0.029163
# mean_data_usage            -0.001427                  0.023264
# Battery Efficiency         -0.020930                 -0.188040
# max_perc                   -0.019377                  0.956385
# min_perc                   -0.023914                  0.955253
#
#                             Screen On Time (hours/day)  \
# ...

# %%
#Heatmap visualization 
  #setting figure cube size
plt.figure(figsize=(9,6))
  #mapping correlation with the correlation matrix of Dataset
sb.heatmap(correlation_matrix,annot=True,cmap='Blues')
plt.title("Correlation Heatmap",fontweight='bold')
  #to assign x-axis labels as the column names
plt.xticks(rotation=45, ha='right')
  #display the heatmap
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Box Plot

# %%
#Boxplot Visualization
plot= DS.select_dtypes(['float', 'int'])
  #x-axis:a condition, y-axis:a column
x= plot[plot['Number of Apps Installed'] <50]
  #creating a boxplot on dataset "x" based on column value  
sb.boxplot(data=x, y='Number of Apps Installed', showfliers=True,color="#2ABDBD")
plt.title('Boxplot', fontweight='bold', pad=10)
plt.show()

# %% [markdown]
# ## Histogram with KDE

# %%
 #To create a Histogram with KDE(Kernel Density Estimate) curve
sb.displot(x.Age, kde=True)

# %% [markdown]
# ## Pie-Chart

# %%
 #to find the number of users using a particular mobile model using value_counts()
user_count= DS['Device Model'].value_counts()
print(user_count)
# Out:
# Device Model
# Xiaomi Mi 11          146
# iPhone 12             146
# Google Pixel 5        142
# OnePlus 9             133
# Samsung Galaxy S21    133
# Name: count, dtype: int64

# %%
 #Pie-Chart for representing the user count of Mobile Models
crs=['#FF7F7F','#4682B4','#98F898','#87CEEB','#008080'] 
plt.pie(user_count, labels=DS['Device Model'].value_counts().index,colors=crs,autopct='%1.1f%%')
plt.title('Pie Sections of User')
plt.show()

# %% [markdown]
# ## 3D Scatter Plot

# %%
 #Creating figure for 3D Scatter Plot
fig= plt.figure(figsize=(6,6))
  #Adding subplots
sub= fig.add_subplot(111, projection='3d')
colors=['green' if val>2000 else 'purple' if val<1000 else 'orange' for val in DS['Battery Drain (mAh/day)']]
  #Giving 3 column values for 3 Dimensional plot
sc=sub.scatter(DS['Number of Apps Installed'],DS['Data Usage (MB/day)'],DS['Battery Drain (mAh/day)'],color=colors)
sub.set_title('3D Scatter Plot')
sub.set_xlabel('X Axis')
sub.set_ylabel('Y Axis')
sub.set_zlabel('Z Axis')
plt.show()

# %% [markdown]
# ## Donut Chart

# %%
 #Grouping the types of device models and aggregating
data=DS.groupby('Device Model')['Data Usage (MB/day)'].sum()
 #creating Donut chart
plt.pie(data,labels=data.index,autopct='%1.1f%%',wedgeprops=dict(width=0.3))
plt.title('Mobile Model VS Data Usage')
plt.show()
